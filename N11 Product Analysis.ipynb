# %%
import requests
import xml.etree.ElementTree as ET
from io import StringIO

url="https://api.n11.com/ws/ProductService.wsdl"
#headers = {'content-type': 'application/soap+xml'}
headers = {'content-type': 'text/xml'}
body = """<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:sch="http://www.n11.com/ws/schemas">
   <soapenv:Header/>
   <soapenv:Body>
      <sch:GetProductListRequest>
         <auth>
            <appKey>385b6a33-ff12-4b07-bba6-d364216911b5</appKey>
            <appSecret>wXDqVji2mit7Glao</appSecret>
         </auth>
         <pagingData>
            <currentPage>0</currentPage>
            <pageSize>100</pageSize>
         </pagingData>
      </sch:GetProductListRequest>
   </soapenv:Body>
</soapenv:Envelope>"""

body
# Out:
# '<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:sch="http://www.n11.com/ws/schemas">\n   <soapenv:Header/>\n   <soapenv:Body>\n      <sch:GetProductListRequest>\n         <auth>\n            <appKey>385b6a33-ff12-4b07-bba6-d364216911b5</appKey>\n            <appSecret>wXDqVji2mit7Glao</appSecret>\n         </auth>\n         <pagingData>\n            <currentPage>0</currentPage>\n            <pageSize>100</pageSize>\n         </pagingData>\n      </sch:GetProductListRequest>\n   </soapenv:Body>\n</soapenv:Envelope>'

# %%
tmp
# Out:
# '<env:Envelope xmlns:env="http://schemas.xmlsoap.org/soap/envelope/"><env:Header/><env:Body><ns3:GetProductListResponse xmlns="" xmlns:ns3="http://www.n11.com/ws/schemas"><result><status>success</status></result><products><product><currencyAmount>250.00</currencyAmount><currencyType>1</currencyType><displayPrice>192.50</displayPrice><isDomestic>false</isDomestic><id>392590007</id><price>250.00</price><productSellerCode>90021</productSellerCode><approvalStatus>1</approvalStatus><saleStatus>2</saleStatus><stockItems><stockItem><bundle>false</bundle><currencyAmount>250.00</currencyAmount><displayPrice>192.50</displayPrice><optionPrice>250.00</optionPrice><attributes/><id>126757920343</id><quantity>5</quantity><version>1</version></stockItem></stockItems><subtitle>40 Kg Elektronik Terazi Manav Terazisi Bakkal Terazisi</subtitle><title>40 Kg Elektronik Terazi Manav Terazisi Bakkal Terazisi</title></product><product><currencyAmount>420.00</currencyAmount><currencyType>1</currencyType><displayPrice>336.00</displayPrice><isDomestic>false</isDomestic><id>392585195</id><price>420.00</price><productSellerCode>90020</productSellerCode><approvalStatus>1</approvalStatus><saleStatus>2</saleStatus><stockItems><stockItem><bundle>false</bundle><currencyAmount>420.00</currencyAmount><displayPrice>336.00</displayPrice><optionPrice>420.00</optionPrice><attributes/><id>126757920341</id><quantity>5</quantity><version>1</version></stockItem></stockItems><subtitle>HIZLI ÜCRETSİZ KARGO</subtitle><title>Concord Plus7go 1GB Ram 16GB Hafıza Tablet Pc Bilgisayar</title></product><product><currencyAmount>220.00</currencyAmount><currencyType>1</currencyType><displayPrice>112.20</displayPrice><isDomestic>false</isDomestic><id>392576941</id><price>220.00</price><productSellerCode>90018</productSellerCode><approvalStatus>1</approvalStatus><saleStatus>2</saleStatus><stockItems><stockItem><bundle>false</bundle><currencyAmount>220.00</currencyAmount><displayPrice>112.20</displayPrice><optionPrice>220.00</optionPrice><attributes/><id>126757920340</id><quantity>10</quantity><version>1</version></stockItem></stockItems><subtitle>Dearling RF-3033 Epilasyon Aleti 3 in 1</subtitle><title>Dearling RF-3033 Epilasyon Aleti 3 in 1</title></product><product><currencyAmount>220.00</currencyAmount><currencyType>1</currencyType><displayPrice>112.20</displayPrice><isDomestic>false</isDomestic><id>392574501</id><price>220.00</price><productSellerCode>90019</productSellerCode><approvalStatus>1</approvalStatus><saleStatus>2</saleStatus><stockItems><stockItem><bundle>false</bundle><currencyAmount>220.00</currencyAmount><displayPrice>112.20</displayPrice><optionPrice>220.00</optionPrice><attributes/><id>126757920338</id><quantity>10</quantity><version>1</version></stockItem></stockItems><subtitle>Dearling RF-7006 Çok Amaçlı Tırnak Törpüsü Topuk Taşı Epilatör</subtitle><title>Dearling RF-7006 Çok Amaçlı Tırnak Törpüsü Topuk Taşı Epilatör</title></product><product><currencyAmount>82.00</currencyAmount><currencyType>1</currencyType><displayPrice>82.00</displayPrice><isDomestic>false</isDomestic><id>392571869</id><price>82.00</price><productSellerCode>900015</productSellerCode><approvalStatus>1</approvalStatus><saleStatus>2</saleStatus><stockItems><stockItem><bundle>false</bundle><currencyAmount>82.00</currencyAmount><displayPrice>82.00</displayPrice><optionPrice>82.00</optionPrice><attributes/><id>126757920337</id><quantity>10</quantity><version>1</version></stockItem></stockItems><subtitle>HIZLI ÜCRETSİZ KARGO</subtitle><title>Concord C-789 BT | TF | USB | FM | LCD Saat Alarmlı Hoparlör</title></product><product><currencyAmount>339.00</currencyAmount><currencyType>1</currencyType><displayPrice>294.93</displayPrice><isDomestic>false</isDomestic><id>392568219</id><price>339.00</price><productSellerCode>900014</productSellerCode><approvalStatus>1</approvalStatus><saleStatus>2</saleStatus><stockItems><stockItem><bundle>false</bundle><currencyAmount>339.00</currencyAmount><displayPrice>294. ...

# %%
type(tmp)
# Out:
# str

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-caa605ec0151> in <module>
#       1 root = ET.fromstring(tmp)
# ----> 2 root = tree.getroot()
#
# NameError: name 'tree' is not defined

# %%
root.tag

# %%
root = ET.fromstring(tmp)
